# %% [markdown]
# # 07 Final Project — IMU-Based Respiratory Validation
#
# Phase A analyses for the final project: multi-sensor validation of paced-breathing LF/HF band migration.
#
# **Analyses:**
# - A1: IMU z-axis PSD for all 5 paced-breathing rates
# - A2: Multi-sensor coupling (cross-correlation, coherence, zero-lag r)
# - A3: Reference hierarchy lag (IMU → HR)
# - A4: IMU respiratory frequency overlay on RR PSD

# %%
# Run the full analysis script
# %run ../scripts/run_07_fp_imu_validation.py
